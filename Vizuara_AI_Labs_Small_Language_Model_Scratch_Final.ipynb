# %% [markdown]
# # Introduction
#
# Let us build a Small Language Model (SLM) from scratch. We will try to keep the parameter size to 50-60 million.
#
# Our goal is to generate creative and coherent text based on the input data.

# %%
import torch

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("No GPU found, running on CPU.")
# Out:
# PyTorch Version: 2.6.0+cu124
# CUDA Available: True
# Device Name: NVIDIA GeForce RTX 3050 Laptop GPU
# VRAM: 4.3 GB

# %% [markdown]
# ## Step 1: Import the Dataset
#
# TinyStories is a synthetic dataset of short stories that only contain words that a typical 3 to 4-year-olds usually understand, generated by GPT-3.5 and GPT-4. We can get it from HuggingFace.

# %%
with open("pubmed_corpus.txt", "r", encoding="utf-8") as f:
    text = f.read()

print(f"Total characters: {len(text):,}")
print(text[:500])
# Out:
# Total characters: 41,322,660
# Magnetic resonance spectroscopic imaging (MRSI) is a powerful molecular imaging modality but has very limited speed, resolution, and SNR tradeoffs. Construction of a low-dimensional model to effectively reduce the dimensionality of the imaging problem has recently shown great promise in improving these tradeoffs. This paper presents a new approach to model and reconstruct the spectroscopic signals by learning a nonlinear low-dimensional representation of the general MR spectra. Specifically, we

# %% [markdown]
# ## Step 2: Tokenize the Dataset
#
# In this step, we will do the following:
#
# (1) Tokenize the dataset into tokenIDs.
#
# (2) Create a file called "train.bin" and "validtion.bin" where we will store the tokenIDs from the entire dataset.
#
# (3) We make sure the tokenIDs are stored on a disk, rather than on the RAM for efficient computations.

# %%
# !pip install tiktoken
import tiktoken, numpy as np, os

enc = tiktoken.get_encoding("gpt2")
token_ids = np.array(enc.encode_ordinary(text), dtype=np.uint16)

split_idx = int(0.9 * len(token_ids))
train_ids, val_ids = token_ids[:split_idx], token_ids[split_idx:]

if not os.path.exists("train.bin"):
    arr = np.memmap("train.bin", dtype=np.uint16, mode="w+", shape=(len(train_ids),))
    arr[:] = train_ids; arr.flush()

if not os.path.exists("validation.bin"):
    arr = np.memmap("validation.bin", dtype=np.uint16, mode="w+", shape=(len(val_ids),))
    arr[:] = val_ids; arr.flush()

print(f"Train: {len(train_ids):,} tokens | Val: {len(val_ids):,} tokens")
# Out:
# Requirement already satisfied: tiktoken in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hetanshi shah\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.26.0->tiktoken) (2025.6.15)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Train: 7,231,048 tokens | Val: 803,450 tokens

# %% [markdown]
# ## Step 3: Create Input-Output batches for the dataset

# %%
# Some functions from https://github.com/karpathy/nanoGPT/blob/master/train.py with slight modifications
#block size = context window
def get_batch(split):
    # We recreate np.memmap every batch to avoid a memory leak, as per
    # https://stackoverflow.com/questions/45132940/numpy-memmap-memory-usage-want-to-iterate-once/61472122#61472122
    if split == 'train':
        data = np.memmap('train.bin', dtype=np.uint16, mode='r')
    else:
        data = np.memmap('validation.bin', dtype=np.uint16, mode='r')
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([torch.from_numpy((data[i:i+block_size]).astype(np.int64)) for i in ix])
    y = torch.stack([torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64)) for i in ix])
    if device_type == 'cuda':
        # pin arrays x,y, which allows us to move them to GPU asynchronously (non_blocking=True)
        x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
    else:
        x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ## Step 4: Define the SLM Model Architecture

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from dataclasses import dataclass
import numpy as np
from tqdm.auto import tqdm
from contextlib import nullcontext
import os

class LayerNorm(nn.Module):
    def __init__(self, ndim, bias):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(ndim))
        self.bias = nn.Parameter(torch.zeros(ndim)) if bias else None
    def forward(self, x):
        return F.layer_norm(x, self.weight.shape, self.weight, self.bias, 1e-5)

class CausalSelfAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.flash = hasattr(F, 'scaled_dot_product_attention')
        if not self.flash:
            self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                       .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        q, k, v = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)

        if self.flash:
            y = F.scaled_dot_product_attention(q, k, v, attn_mask=None, dropout_p=self.attn_dropout.p if self.training else 0.0, is_causal=True)
        else:
            att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
            att = att.masked_fill(self.bias[:, :, :T, :T] == 0, float('-inf'))
            att = F.softmax(att, dim=-1)
            att = self.attn_dropout(att)
            y = att @ v

        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.resid_dropout(self.c_proj(y))
        return y

class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.c_fc = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.gelu = nn.GELU()
        self.c_proj = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.dropout = nn.Dropout(config.dropout)
    def forward(self, x):
        return self.dropout(self.c_proj(self.gelu(self.c_fc(x))))

class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ln1 = LayerNorm(config.n_embd, config.bias)
        self.attn = CausalSelfAttention(config)
        self.ln2 = LayerNorm(config.n_embd, config.bias)
        self.mlp = MLP(config)
    def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

@dataclass
class GPTConfig:
    block_size: int
    vocab_size: int
    n_layer: int
    n_head: int
    n_embd: int
    dropout: float = 0.0
    bias: bool = True

class GPT(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.transformer = nn.ModuleDict(dict(
            wte=nn.Embedding(config.vocab_size, config.n_embd),
            wpe=nn.Embedding(config.block_size, config.n_embd),
            drop=nn.Dropout(config.dropout),
            h=nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f=LayerNorm(config.n_embd, config.bias),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight  # weight tying

        self.apply(self._init_weights)
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                nn.init.normal_(p, mean=0.0, std=0.02 / math.sqrt(2 * config.n_layer))

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.config.block_size
        pos = torch.arange(0, t, dtype=torch.long, device=device)

        tok_emb = self.transformer.wte(idx)
        pos_emb = self.transformer.wpe(pos)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)

        if targets is not None:
            logits = self.lm_head(x)
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
            return logits, loss
        else:
            logits = self.lm_head(x[:, [-1], :])
            return logits, None

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=None):
        """
        Generate tokens given a conditioning sequence.
        idx: Tensor of shape (B, T)
        """
        for _ in range(max_new_tokens):
            idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            if top_k is not None:
                v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
                logits[logits < v[:, [-1]]] = -float('Inf')
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
config = GPTConfig(
    vocab_size=50257,     # use the tokenizer's vocab size
    block_size=128,       # or whatever context size you're training with
    n_layer=6,
    n_head=6,
    n_embd=384,
    dropout=0.1,
    bias=True
)

model = GPT(config)

# %% [markdown]
# ## Step 5: Define the loss function

# %%
def estimate_loss(model):
    out = {}
    model.eval()
    with torch.inference_mode():
        for split in ['train', 'val']:
            losses = torch.zeros(eval_iters)
            for k in range(eval_iters):
                X, Y = get_batch(split)
                with ctx:
                    logits, loss = model(X, Y)
                losses[k] = loss.item()
            out[split] = losses.mean()
    model.train()
    return out

# %% [markdown]
# ## Step 6: Define SLM Training Configuration Part 1

# %%
# Training Config
import torch
from contextlib import nullcontext

learning_rate = 1e-4 #more stable training, earlier 1e-4
max_iters = 50000 #increase from 25000
warmup_steps = 2000 #smoother initial train, earlier 100
min_lr = 5e-4 #lower rate, earlier 5e-4
eval_iters = 500 # increased from 100
batch_size = 8 # changed from 16, better gradient estimate
block_size = 128 #changed from 64, capture longer range dependencies

gradient_accumulation_steps = 128 # reduced from 50

device =  "cuda" if torch.cuda.is_available() else "cpu"
device_type = 'cuda' if 'cuda' in device else 'cpu' # for later use in torch.autocast
# note: float16 data type will automatically use a GradScaler

# How to use autocast https://wandb.ai/wandb_fc/tips/reports/How-To-Use-Autocast-in-PyTorch--VmlldzoyMTk4NTky
#dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
dtype = 'float16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]

ctx = nullcontext() if device_type == 'cpu' else torch.amp.autocast(device_type=device_type, dtype=ptdtype)

torch.set_default_device(device)
torch.manual_seed(42)

# %% [markdown]
# ## Step 7: Define SLM Training Configuration Part 2

# %%
from torch.optim.lr_scheduler import LinearLR,SequentialLR, CosineAnnealingLR

##PUT IN WEIGHT DECAY, CHANGED BETA2 to 0.95
optimizer =  torch.optim.AdamW(model.parameters(), lr=learning_rate, betas=(0.9, 0.95), weight_decay=0.1, eps=1e-9) #weight decay for regularization

scheduler_warmup = LinearLR(optimizer, total_iters = warmup_steps) #Implement linear warmup
scheduler_decay = CosineAnnealingLR(optimizer,T_max = max_iters - warmup_steps, eta_min = min_lr) #Implement lr decay
scheduler = SequentialLR(optimizer, schedulers=[scheduler_warmup, scheduler_decay], milestones=[warmup_steps]) #Switching from warmup to decay

# https://stackoverflow.com/questions/72534859/is-gradscaler-necessary-with-mixed-precision-training-with-pytorch
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# Out:
# C:\Users\HETANSHI SHAH\AppData\Local\Temp\ipykernel_1052\2132813893.py:11: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))

# %% [markdown]
# ## Step 8: Pre-train the SLM

# %%
train_loss_list, validation_loss_list = [], []

best_val_loss = float('inf')
best_model_params_path = "best_model_params.pt"
last_model_params_path = "last_model_params.pt"
model = model.to(device)

for epoch in tqdm(range(max_iters)):
    if epoch % eval_iters == 0 and epoch != 0:
        losses = estimate_loss(model)
        print(f"Epoch {epoch}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        train_loss_list.append(losses['train'])
        validation_loss_list.append(losses['val'])

        # Save best model
        if losses['val'] < best_val_loss:
            best_val_loss = losses['val']
            # Delete previous last checkpoint to save space
            if os.path.exists(last_model_params_path):
                os.remove(last_model_params_path)
            # Move current best to last
            if os.path.exists(best_model_params_path):
                os.rename(best_model_params_path, last_model_params_path)
            torch.save(model.state_dict(), best_model_params_path)
            print(f"✓ New best: {best_val_loss:.4f}")

    X, y = get_batch("train")
    X, y = X.to(device), y.to(device)

    with ctx:
        logits, loss = model(X, y)
        loss = loss / gradient_accumulation_steps
        scaler.scale(loss).backward()

    if ((epoch + 1) % gradient_accumulation_steps == 0) or (epoch + 1 == max_iters):
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad(set_to_none=True)
    scheduler.step()
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# Epoch 500: train loss 10.4516, val loss 10.4494
# ✓ New best: 10.4494
# Epoch 1000: train loss 10.2517, val loss 10.2439
# ✓ New best: 10.2439
# Epoch 1500: train loss 10.1636, val loss 10.1617
# ✓ New best: 10.1617
# Epoch 2000: train loss 10.0929, val loss 10.0864
# ✓ New best: 10.0864
# Epoch 2500: train loss 10.0068, val loss 9.9979
# ✓ New best: 9.9979
# Epoch 3000: train loss 9.9210, val loss 9.9124
# ✓ New best: 9.9124
# Epoch 3500: train loss 9.8327, val loss 9.8237
# ✓ New best: 9.8237
# Epoch 4000: train loss 9.7282, val loss 9.7244
# ✓ New best: 9.7244
# Epoch 4500: train loss 9.6152, val loss 9.6155
# ✓ New best: 9.6155
# Epoch 5000: train loss 9.5211, val loss 9.5193
# ✓ New best: 9.5193
# Epoch 5500: train loss 9.4479, val loss 9.4418
# ✓ New best: 9.4418
# Epoch 6000: train loss 9.3391, val loss 9.3350
# ✓ New best: 9.3350
# Epoch 6500: train loss 9.2436, val loss 9.2308
# ✓ New best: 9.2308
# Epoch 7000: train loss 9.1361, val loss 9.1212
# ✓ New best: 9.1212
# Epoch 7500: train loss 9.0312, val loss 9.0301
# ✓ New best: 9.0301
# Epoch 8000: train loss 8.9247, val loss 8.9236
# ✓ New best: 8.9236
# Epoch 8500: train loss 8.8206, val loss 8.8244
# ✓ New best: 8.8244
# Epoch 9000: train loss 8.7185, val loss 8.7330
# ✓ New best: 8.7330
# Epoch 9500: train loss 8.6206, val loss 8.6180
# ✓ New best: 8.6180
# Epoch 10000: train loss 8.5126, val loss 8.5296
# ✓ New best: 8.5296
# Epoch 10500: train loss 8.4070, val loss 8.4262
# ✓ New best: 8.4262
# Epoch 11000: train loss 8.3414, val loss 8.3418
# ✓ New best: 8.3418
# Epoch 11500: train loss 8.2273, val loss 8.2293
# ✓ New best: 8.2293
# Epoch 12000: train loss 8.1094, val loss 8.1386
# ✓ New best: 8.1386
# Epoch 12500: train loss 7.9986, val loss 8.0291
# ✓ New best: 8.0291
# Epoch 13000: train loss 7.9115, val loss 7.9310
# ✓ New best: 7.9310
# Epoch 13500: train loss 7.8032, val loss 7.8301
# ✓ New best: 7.8301
# Epoch 14000: train loss 7.7096, val loss 7.7488
# ✓ New best: 7.7488
# Epoch 14500: train loss 7.5993, val loss 7.6511
# ✓ New best: 7.6511
# Epoch 15000: train loss 7.5243, val loss 7.5597
# ✓ New best: 7.5597
# Epoch 15500: train loss 7.4590, val loss 7.4971
# ✓ New best: 7.4971
# Epoch 16000: train loss 7.3834, val loss 7.4352
# ✓ New best: 7.4352
# Epoch 16500: train loss 7.3311, val loss 7.3779
# ✓ New best: 7.3779
# Epoch 17000: train loss 7.2738, val loss 7.3232
# ✓ New best: 7.3232
# Epoch 17500: train loss 7.1917, val loss 7.2815
# ✓ New best: 7.2815
# Epoch 18000: train loss 7.1424, val loss 7.2237
# ✓ New best: 7.2237
# Epoch 18500: train loss 7.0885, val loss 7.1605
# ✓ New best: 7.1605
# Epoch 19000: train loss 7.0342, val loss 7.1264
# ✓ New best: 7.1264
# Epoch 19500: train loss 6.9960, val loss 7.0801
# ✓ New best: 7.0801
# Epoch 20000: train loss 6.9562, val loss 7.0336
# ✓ New best: 7.0336
# Epoch 20500: train loss 6.8880, val loss 6.9847
# ✓ New best: 6.9847
# Epoch 21000: train loss 6.8394, val loss 6.9476
# ✓ New best: 6.9476
# Epoch 21500: train loss 6.8135, val loss 6.9087
# ✓ New best: 6.9087
# Epoch 22000: train loss 6.7801, val loss 6.8939
# ✓ New best: 6.8939
# Epoch 22500: train loss 6.7263, val loss 6.8420
# ✓ New best: 6.8420
# Epoch 23000: train loss 6.6720, val loss 6.7868
# ✓ New best: 6.7868
# Epoch 23500: train loss 6.6404, val loss 6.7778
# ✓ New best: 6.7778
# Epoch 24000: train loss 6.5931, val loss 6.7280
# ✓ New best: 6.7280
# Epoch 24500: train loss 6.5482, val loss 6.6898
# ✓ New best: 6.6898
# Epoch 25000: train loss 6.5154, val loss 6.6565
# ✓ New best: 6.6565
# Epoch 25500: train loss 6.4743, val loss 6.6312
# ✓ New best: 6.6312
# Epoch 26000: train loss 6.4320, val loss 6.5741
# ✓ New best: 6.5741
# Epoch 26500: train loss 6.3904, val loss 6.5446
# ✓ New best: 6.5446
# Epoch 27000: train loss 6.3659, val loss 6.5111
# ✓ New best: 6.5111
# Epoch 27500: train loss 6.3237, val loss 6.4972
# ✓ New best: 6.4972
# Epoch 28000: train loss 6.3009, val loss 6.4574
# ✓ New best: 6.4574
# Epoch 28500: train loss 6.2578, val loss 6.4322
# ✓ New best: 6.4322
# Epoch 29000: train loss 6.2413, val loss 6.4018
# ✓ New best: 6.4018
# Epoch 29500: train loss 6.1968, val loss 6.3746
# ✓ New best: 6.3746
# Epoch 30000: train loss 6.1694, val loss 6.3349
# ✓ New best: 6.3349
# Epoch 30500: train loss 6.1311, val loss 6.3135
# ✓ New best: 6.3135
# Epoch 31000: train loss 6.1270, val loss 6.2900
# ✓ New best: 6.2900
# Epoch 31500: train loss 6.0772, val loss 6.2821
# ✓ New best: 6.2821
# Epoch 32000: train loss 6.0622, val loss 6.2509
# ✓ New best: 6.2509
# Epoch 32500: train loss 6.0454, val loss 6.2415
# ✓ New best: 6.2415
# Epoch 33000: train loss 6.0190, val loss 6.1991
# ✓ New best: 6.1991
# Epoch 33500: train loss 5.9877, val loss 6.1868
# ✓ New best: 6.1868
# Epoch 34000: train loss 5.9832, val loss 6.1562
# ✓ New best: 6.1562
# Epoch 34500: train loss 5.9339, val loss 6.1395
# ✓ New best: 6.1395
# Epoch 35000: train loss 5.9171, val loss 6.1344
# ✓ New best: 6.1344
# Epoch 35500: train loss 5.8929, val loss 6.1010
# ✓ New best: 6.1010
# Epoch 36000: train loss 5.8885, val loss 6.0899
# ✓ New best: 6.0899
# Epoch 36500: train loss 5.8514, val loss 6.0599
# ✓ New best: 6.0599
# Epoch 37000: train loss 5.8238, val loss 6.0376
# ✓ New best: 6.0376
# Epoch 37500: train loss 5.8021, val loss 6.0323
# ✓ New best: 6.0323
# Epoch 38000: train loss 5.7746, val loss 6.0052
# ✓ New best: 6.0052
# Epoch 38500: train loss 5.7824, val loss 6.0131
# Epoch 39000: train loss 5.7503, val loss 5.9745
# ✓ New best: 5.9745
# Epoch 39500: train loss 5.7160, val loss 5.9655
# ✓ New best: 5.9655
# Epoch 40000: train loss 5.7086, val loss 5.9470
# ✓ New best: 5.9470
# Epoch 40500: train loss 5.6824, val loss 5.9269
# ✓ New best: 5.9269
# Epoch 41000: train loss 5.6547, val loss 5.9001
# ✓ New best: 5.9001
# Epoch 41500: train loss 5.6495, val loss 5.8981
# ✓ New best: 5.8981
# Epoch 42000: train loss 5.6379, val loss 5.8982
# Epoch 42500: train loss 5.6161, val loss 5.8621
# ✓ New best: 5.8621
# Epoch 43000: train loss 5.6148, val loss 5.8499
# ✓ New best: 5.8499
# Epoch 43500: train loss 5.6011, val loss 5.8556
# Epoch 44000: train loss 5.5673, val loss 5.8312
# ✓ New best: 5.8312
# Epoch 44500: train loss 5.5596, val loss 5.8062
# ✓ New best: 5.8062
# Epoch 45000: train loss 5.5209, val loss 5.7985
# ✓ New best: 5.7985
# Epoch 45500: train loss 5.5033, val loss 5.7729
# ✓ New best: 5.7729
# Epoch 46000: train loss 5.4895, val loss 5.7627
# ✓ New best: 5.7627
# Epoch 46500: train loss 5.4806, val loss 5.7352
# ✓ New best: 5.7352
# Epoch 47000: train loss 5.4520, val loss 5.7322
# ✓ New best: 5.7322
# Epoch 47500: train loss 5.4489, val loss 5.7085
# ✓ New best: 5.7085
# Epoch 48000: train loss 5.4541, val loss 5.7093
# Epoch 48500: train loss 5.4309, val loss 5.6982
# ✓ New best: 5.6982
# Epoch 49000: train loss 5.4126, val loss 5.6970
# ✓ New best: 5.6970
# Epoch 49500: train loss 5.3726, val loss 5.6535
# ✓ New best: 5.6535

# %% [markdown]
# ## Step 9: Plot the SLM Loss Function

# %%
import matplotlib.pyplot as plt
train_loss_list_converted = [i.cpu().detach() for i in train_loss_list]
validation_loss_list_converted = [i.cpu().detach() for i in validation_loss_list]

plt.plot(train_loss_list_converted, 'g', label='train_loss')
plt.plot(validation_loss_list_converted, 'r', label='validation_loss')
plt.xlabel("Steps - Every 200 steps")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Step 10: Run SLM Inference on our trained model

# %%
#Load the model
model = GPT(config)  # re-create the model with same config
device =  "cuda" if torch.cuda.is_available() else "cpu"
best_model_params_path = "best_model_params.pt"
model.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
model = model.to(device)  # ADD THIS
model.eval()
# Out:
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 384)
#     (wpe): Embedding(128, 384)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x Block(
#         (ln1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=384, out_features=1152, bias=True)
#           (c_proj): Linear(in_features=384, out_features=384, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=384, out_features=50257, bias=False)
# )

# %%
prompts = [
    "The effects of COVID-19 on",
    "Patients diagnosed with type 2 diabetes",
    "A randomized controlled trial of",
    "MRI imaging results suggest",
]
for prompt in prompts:
    context = torch.tensor(enc.encode_ordinary(prompt)).unsqueeze(0).to(device)
    y = model.generate(context, max_new_tokens=200, temperature=0.8, top_k=40)
    print(f"\n--- {prompt} ---")
    print(enc.decode(y.squeeze().tolist()))
# Out:
# --- The effects of COVID-19 on ---
# The effects of COVID-19 on COVID-19. It is a novel coronavirus (PEDOT) in SARS-19, and its effect of a 2 (SARS-2) were used to be considered for COVID-CoV-19 patients. This review is currently used in the role of COVID-19 is the COVID-19. We have been used in this research as a coronavirus disease and to the SARS-2, or the COVID-19) has to help the coronavirus disease in recent years with COVID-19 infection, and in the COVID-19.
#
#
# Deep learning and coronavirus disease (COVID-19) was to the risk of COVID-19, and COVID-19) has been proposed. In addition to perform the first to the outbreak of COVID-19 has a pandemic has been achieved the COVID-19. The virus that some to a spread of COVID-19 outbreak
#
# --- Patients diagnosed with type 2 diabetes ---
# Patients diagnosed with type 2 diabetes.0.7% and 0.8% for the DNN of the accuracy of 0.2. 0. The proposed method is an emerging approach (p=0.0. 0.0.15.3) and 0. The proposed method can be performed for the accuracy of the proposed method for the proposed method for a new machine learning and is considered as a model (VR) for the proposed.
#
# In particular, we have an efficient and the current-based training is the main number of the main analysis of a novel CNNs which can be used for the neural network in recent years and to assess a novel model. Here we demonstrate that the classification of the classification of deep learning framework for the deep learning method for multiple machine learning and the proposed method. To address this study, we propose a novel method for all the novel deep learning approach for the deep learning. In this network (DL) model to identify the proposed model have reported to improve the proposed method, and
#
# --- A randomized controlled trial of ---
# A randomized controlled trial of a virtual reality. A virtual reality simulator as the VR was also to be an alternative to reduce the system. The proposed method was also associated with the virtual reality is the same-dependent training.
#
# The main study was to address this problem for surgical training by a virtual reality, and the brain-computer (EEG) is also be able to investigate the use of the real-based and control. The aim of this review were applied to the environment, and the virtual reality (BC) and the use of virtual environment (e., the performance with the first of the same time), and a virtual reality (S and the VR virtual reality environment. The present study was to the BCI systems of the virtual reality (e., the first time) of the VR) and in the training. This approach is an important to improve the task of the first time. The BCI method was to the same task of the first. The results obtained from the study was to the study was performed
#
# --- MRI imaging results suggest ---
# MRI imaging results suggest that our data from the potential to the brain network connectome. To address this study, we investigated the main objective of a novel model using a novel method to create a method for a deep learning strategy for a method.
#
# We propose a deep learning method for the deep network with a deep learning model. In this paper, we present a model to assess the network, which can be achieved an efficient method (EEG) to determine the proposed in a large number of the network. The model outperforms these two-based system can be used in virtual-based deep learning for the proposed method. The model, and the two-learning models are tested on a deep learning and the task in contrast and the proposed method. A linear learning architecture was found to predict and show that, and the performance, respectively). Results show that the two types of the use of the proposed method achieved on the proposed method is used and to reduce the classification of the model of the classification. In this work,

# %%
# from google.colab import runtime
# runtime.unassign()
